# %%
import keras
from keras import layers
import numpy as np

# %%
original_dim = 28 * 28
intermediate_dim = 64
latent_dim = 10

inputs = keras.Input(shape=(original_dim,))
h = layers.Dense(intermediate_dim, activation='relu')(inputs)
z_mean = layers.Dense(latent_dim)(h)
z_log_sigma = layers.Dense(latent_dim)(h)
print(z_mean.shape)
# Out:
# (None, 10)

# %%
from keras import backend as K

def sampling(args):
    z_mean, z_log_sigma = args
    # epsilon = alpha
    #make random stddev, mean
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=0.1)
    # sample = mean(u) + alpha(epsilon) * standard diviation
    return z_mean + K.exp(z_log_sigma) * epsilon

# %%
z = layers.Lambda(sampling)([z_mean, z_log_sigma])

# %%
# Create encoder (sub model)
encoder = keras.Model(inputs, [z_mean, z_log_sigma, z], name='encoder')

# Create decoder
latent_inputs = keras.Input(shape=(latent_dim,), name='z_sampling')
x = layers.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = layers.Dense(original_dim, activation='sigmoid')(x)
decoder = keras.Model(latent_inputs, outputs, name='decoder')

# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = keras.Model(inputs, outputs, name='vae_mlp')
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 784)]        0           []
#
#  dense_10 (Dense)               (None, 64)           50240       ['input_3[0][0]']
#
#  dense_11 (Dense)               (None, 10)           650         ['dense_10[0][0]']
#
#  dense_12 (Dense)               (None, 10)           650         ['dense_10[0][0]']
#
#  lambda_2 (Lambda)              (None, 10)           0           ['dense_11[0][0]',
#                                                                   'dense_12[0][0]']
#
# ==================================================================================================
# Total params: 51,540
# Trainable params: 51,540
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
reconstruction_loss = keras.losses.binary_crossentropy(inputs, outputs)
reconstruction_loss *= original_dim
kl_loss = 1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)

# %%
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# %%
vae.compile(optimizer='adam', loss='binary_crossentropy')

# %%
vae.fit(x_train, x_train,
        epochs=100,
        batch_size=32)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.8986
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 117.1903
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 110.5241
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 106.7675
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 104.6902
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 103.3296
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 102.3643
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 101.6524
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 101.1143
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 100.6605
# Epoch 11/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 100.3000
# Epoch 12/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 100.0039
# Epoch 13/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 99.7267
# Epoch 14/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 99.4885
# Epoch 15/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 99.2974
# Epoch 16/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 99.0827
# Epoch 17/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 98.9255
# Epoch 18/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 98.7155
# Epoch 19/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 98.5636
# Epoch 20/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 98.4029
# Epoch 21/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 98.2821
# Epoch 22/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 98.1499
# Epoch 23/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 98.0277
# Epoch 24/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 97.9104
# Epoch 25/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 97.8065
# Epoch 26/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 97.6752
# Epoch 27/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 97.5815
# Epoch 28/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 97.4953
# Epoch 29/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 97.3969
# Epoch 30/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 97.3309
# Epoch 31/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 97.2455
# Epoch 32/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 97.1640
# Epoch 33/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 97.0762
# Epoch 34/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 97.0147
# Epoch 35/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 96.9528
# Epoch 36/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 96.9213
# Epoch 37/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 96.8494
# Epoch 38/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 96.8082
# Epoch 39/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 96.7323
# Epoch 40/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 96.6914
# Epoch 41/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 96.6466
# Epoch 42/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 96.6034
# Epoch 43/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 96.5494
# Epoch 44/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 96.5244
# Epoch 45/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 96.5091
# Epoch 46/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 96.4255
# Epoch 47/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 96.4015
# Epoch 48/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 96.3733
# Epoch 49/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 96.3002
# Epoch 50/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 96.2876
# Epoch 51/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 96.2559
# Epoch 52/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 96.1903
# Epoch 53/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 96.1938
# Epoch 54/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 96.1497
# Epoch 55/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 96.1309
# Epoch 56/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 96.1020
# Epoch 57/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 96.0484
# Epoch 58/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 96.0355
# Epoch 59/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 96.0101
# Epoch 60/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.9849
# Epoch 61/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 95.9634
# Epoch 62/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 95.9341
# Epoch 63/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.9022
# Epoch 64/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.8572
# Epoch 65/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 95.8552
# Epoch 66/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.8227
# Epoch 67/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 95.8003
# Epoch 68/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.7510
# Epoch 69/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.7283
# Epoch 70/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.6940
# Epoch 71/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.6985
# Epoch 72/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 95.6512
# Epoch 73/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.6442
# Epoch 74/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.6328
# Epoch 75/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 95.6148
# Epoch 76/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 95.5814
# Epoch 77/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 95.5630
# Epoch 78/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 95.5628
# Epoch 79/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 95.5278
# Epoch 80/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 95.5003
# Epoch 81/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 95.4597
# Epoch 82/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 95.4670
# Epoch 83/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 95.4341
# Epoch 84/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 95.4104
# Epoch 85/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 95.4286
# Epoch 86/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 95.4200
# Epoch 87/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 95.3606
# Epoch 88/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 95.3737
# Epoch 89/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.3592
# Epoch 90/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.3482
# Epoch 91/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.3076
# Epoch 92/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 95.3046
# Epoch 93/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 95.2770
# Epoch 94/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.2851
# Epoch 95/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.2844
# Epoch 96/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.2272
# Epoch 97/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.2445
# Epoch 98/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.2181
# Epoch 99/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 95.2220
# Epoch 100/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 95.1778

# %%
x_decoded = vae.predict(x_train)
# Out:
# 1875/1875 [==============================] - 2s 1ms/step

# %%
import matplotlib.pyplot as plt
# Display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# We will sample n points within [-15, 15] standard deviations
grid_x = np.linspace(-15, 15, n)
grid_y = np.linspace(-15, 15, n)
k=0
for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        #x_decoded = decoder.predict(z_sample)
        digit = x_train[k].reshape(digit_size, digit_size)
        k = k +1
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure)
plt.show()
print (k)
# Out:
# 225

# %%
import matplotlib.pyplot as plt
# Display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# We will sample n points within [-15, 15] standard deviations
grid_x = np.linspace(-15, 15, n)
grid_y = np.linspace(-15, 15, n)
k=0
for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        #x_decoded = decoder.predict(z_sample)
        digit = x_decoded[k].reshape(digit_size, digit_size)
        k = k +1
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure)
plt.show()
